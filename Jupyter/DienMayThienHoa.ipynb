# %%
#TV Thiên Hòa

from selenium import webdriver as wb
import pandas as pd
from tqdm import tqdm
import time

webD = wb.Chrome('C:\\Users\\Admin\\Downloads\\chromedriver.exe')
webD.get('https://dienmaythienhoa.vn/tivi-c5351.html')

hrefLinkList = []
condition = True
while condition:
    time.sleep(3)
    allInfo = webD.find_elements_by_class_name('box')

    for eEle in allInfo:
        temp = eEle.find_elements_by_tag_name('a')
        hrefLink = temp[0].get_property('href')
        hrefLinkList.append(hrefLink)
    try:
        webD.find_elements_by_xpath('/html/body/main/div[2]/div[1]/div[2]/div[5]/div/div/div[2]/div')[-1].click()
    except:
        condition = False

# allInfo = webD.find_elements_by_xpath('//*[@id="scroll-sanpham"]/ul[2]/li')
# for eEle in allInfo:
#     print(eEle.text)
#     print('aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa')
#     temp = eEle.find_elements_by_tag_name('a')
#     print(temp[0].text)
#     hrefLink = temp[0].get_property('href')
#     hrefLinkList.append(hrefLink)

overallinfo = []
for i in tqdm(hrefLinkList):
    webD.get(i)
    nameOftheProduct = webD.find_element_by_class_name('title-top').find_element_by_tag_name('h1').text
    priceoftheProduct = webD.find_element_by_class_name('price-real').text
    #linkImg = webD.find_element_by_class_name('spct-hinhdaidien').get_property('src')
#     descOfProduct = webD.find_element_by_xpath(
#         '//*[@id="__next"]/div[1]/main/div[3]/div/div[2]/div[2]/div[1]/div[1]/div[3]/ul')
    tempJ = {'nameOftheProduct': nameOftheProduct,
             'priceoftheProduct': priceoftheProduct,
#              'descOfProduct': descOfProduct,
             'hyperlink': i}
    overallinfo.append(tempJ)

pd.DataFrame(overallinfo)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 656/656 [32:29<00:00,  2.97s/it]
#                                      nameOftheProduct priceoftheProduct  \
# 0    Smart Tivi SAMSUNG 4K 50 Inch UA50RU7200KXXV LED       10,290,000đ
# 1       Android Tivi SONY 43 Inch KDL-43W800G VN3 LED       10,390,000đ
# 2    Android Tivi SONY 43 Inch KD-43X8000G VN3 LED 4K       11,390,000đ
# 3        Smart Tivi Samsung 4K 43 Inch UA43RU7200KXXV        8,290,000đ
# 4                 Smart Tivi VTB 32 Inch LV3277KS LED        3,790,000đ
# ..                                                ...               ...
# 651  Android Tivi SONY 43 Inch KD-43X8000G VN3 LED 4K       11,390,000đ
# 652     Android Tivi SONY 43 Inch KDL-43W800G VN3 LED       10,390,000đ
# 653  Smart Tivi SAMSUNG 4K 50 Inch UA50RU7200KXXV LED       10,290,000đ
# 654        Smart Tivi Samsung 32 Inch UA32T4500A KXXV        5,890,000đ
# 655        Smart Karaoke Tivi Sansui 43 inch SV4300KS        6,890,000đ
#
#                                              hyperlink
# 0    https://dienmaythienhoa.vn/smart-tivi-samsung-...
# 1    https://dienmaythienhoa.vn/android-tivi-sony-4...
# 2    https://dienmaythienhoa.vn/android-tivi-sony-4...
# 3    https://dienmaythienhoa.vn/smart-tivi-samsung-...
# 4    https://dienmaythienhoa.vn/smart-tivi-vtb-32-i...
# ..                                                 ...
# 651  https://dienmaythienhoa.vn/android-tivi-sony-4...
# 652  https://dienmaythienhoa.vn/android-tivi-sony-4...
# 653  https://dienmaythienhoa.vn/smart-tivi-samsung-...
# 654  https://dienmaythienhoa.vn/smart-tivi-samsung-...
# 655  https://dienmaythienhoa.vn/smart-karaoke-tivi-...
#
# [656 rows x 3 columns]
