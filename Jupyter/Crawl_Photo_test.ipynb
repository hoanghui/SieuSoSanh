# %%
import urllib
import base64
from selenium import webdriver as wb

webD = wb.Chrome('C:\\Users\\Admin\\Downloads\\chromedriver.exe')
webD.get('https://www.nguyenkim.com/acer-aspire-5-a514-53-50ja-i5-1035g1-14-inch.html')

# get the image source
# img = webD.find_element_by_xpath('//*[@id="top-product"]/div[1]/div[2]/ul/li[1]/div/img')
# src = img.get_attribute('src')
with open("SSS.png", "rb") as image_file:
    encoded_string = base64.b64encode(image_file.read())
print(encoded_string)
# encode
# encoded_string = base64.b64encode(src.read())
# print(encoded_string)
webD.close()
# Out:
# b'...'
