_property('href')
        hrefLinkList.append(hrefLink)
    try:
        webD.find_elements_by_class_name('btn_next ')[-1].click()
    except:
        condition = False

overallinfo = []
for i in tqdm(hrefLinkList):
    webD.get(i)
    time.sleep(1)
    nameOftheProduct = webD.find_element_by_class_name('product_info_name').text
    priceoftheProduct = webD.find_element_by_class_name('nk-price-final').text
#     descOfProduct = webD.find_element_by_xpath(
#         '//*[@id="__next"]/div[1]/main/div[3]/div/div[2]/div[2]/div[1]/div[1]/div[3]/ul')
    tempJ = {'nameOftheProduct': nameOftheProduct,
             'priceoftheProduct': priceoftheProduct,
#              'descOfProduct': descOfProduct,
             'hyperlink': i}
    overallinfo.append(tempJ)

pd.DataFrame(overallinfo)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 34/34 [01:29<00:00,  2.63s/it]
#                                      nameOftheProduct priceoftheProduct  \
# 0     Tủ lạnh Toshiba Inverter 253 lít GR-B31VU (UKG)        7.590.000đ
# 1        Tủ lạnh Samsung Inverter 236 lít RT22M4032BU        8.090.000đ
# 2                Tủ lạnh LG Inverter 315 lít GN-D315S        9.490.000đ
# 3     Tủ lạnh Panasonic Inverter 268 lít NR-BL300PKVN       10.490.000đ
# 4        Tủ lạnh Toshiba Inverter 305 lít GR-AG36VUBZ       10.290.000đ
# 5   Tủ lạnh Hitachi Inverter 366 lít R-FG480PGV8 (...       11.900.000đ
# 6   Tủ lạnh Toshiba Inverter 359 lít GR-AG41VPDZ (...       12.740.000đ
# 7               Tủ lạnh LG Inverter 393 lít GN-D422BL       12.490.000đ
# 8              Tủ Lạnh LG Inverter 613 lít GR-B247JDS       18.490.000đ
# 9         Tủ lạnh Sharp Inverter 556 lít SJ-FX631V-SL       18.900.000đ
# 10                Tủ Lạnh Electrolux 92 lít EUM0900SA        2.790.000đ
# 11               Tủ lạnh Aqua 130 lít AQR-T150FA (BS)        3.990.000đ
# 12                 Tủ lạnh Aqua 90 lít AQR-D99FA (BS)        2.790.000đ
# 13       Tủ Lạnh Samsung Inverter 208 lít RT19M300BGS        4.990.000đ
# 14               Tủ lạnh LG Inverter 315 lít GN-D315S        9.490.000đ
# 15                 Tủ lạnh Aqua 50 lít AQR-D59FA (BS)        2.550.000đ
# 16       Tủ lạnh Samsung Inverter 299 lít RT29K5532DX       10.190.000đ
# 17         Tủ lạnh Sharp Inverter 196 lít SJ-X201E-DS        5.590.000đ
# 18  Tủ lạnh Hitachi Inverter 366 lít R-FG480PGV8 (...       11.900.000đ
# 19      Tủ lạnh Aqua Inverter 186 lít AQR-T219FA (PB)        4.990.000đ
# 20   Tủ lạnh Hitachi Inverter 509 lít R-FW650PGV8 GBK       21.500.000đ
# 21       Tủ lạnh Samsung Inverter 280 lít RB27N4010S8       10.490.000đ
# 22         Tủ lạnh Sharp Inverter 253 lít SJ-X281E-SL        6.590.000đ
# 23    Tủ lạnh Toshiba Inverter 253 lít GR-B31VU (UKG)        7.590.000đ
# 24   Tủ Lạnh Toshiba Inverter 194 lít GR-A25VM (UKG1)        6.640.000đ
# 25        Tủ lạnh Sharp Inverter 165 lít SJ-X176E-DSS        4.990.000đ
# 26       Tủ lạnh Samsung inverter 394 lít RT38K5982SL       15.790.000đ
# 27  Tủ lạnh Hitachi Inverter 275 lít R-B330PGV8 (BSL)       10.750.000đ
# 28         Tủ lạnh Sharp Inverter 342 lít SJ-X346E-SL        8.290.000đ
# 29     Tủ lạnh Toshiba Inverter 253 lít GR-B31VU (SK)        6.990.000đ
# 30                Tủ lạnh Electrolux 46 lít EUM0500SB        2.690.000đ
# 31  Tủ lạnh Hitachi Inverter 569 lít R-WB640VGV0 (...       36.900.000đ
# 32  Tủ lạnh Hitachi Inverter 540 lít R-FW690PGV7 (...       28.800.000đ
# 33       Tủ lạnh Samsung Inverter 680 lít RS62R5001M9       17.900.000đ
#
#                                             hyperlink
# 0   https://www.nguyenkim.com/tu-lanh-toshiba-inve...
# 1   https://www.nguyenkim.com/tu-lanh-samsung-inve...
# 2   https://www.nguyenkim.com/tu-lanh-lg-315-lit-g...
# 3   https://www.nguyenkim.com/tu-lanh-panasonic-26...
# 4   https://www.nguyenkim.com/tu-lanh-toshiba-305-...
# 5   https://www.nguyenkim.com/tu-lanh-hitachi-r-fg...
# 6   https://www.nguyenkim.com/tu-lanh-toshiba-359-...
# 7   https://www.nguyenkim.com/tu-lanh-lg-393-lit-g...
# 8   https://www.nguyenkim.com/tu-lanh-lg-613-lit-g...
# 9   https://www.nguyenkim.com/tu-lanh-sharp-556-li...
# 10  https://www.nguyenkim.com/tu-lanh-electrolux-9...
# 11  https://www.nguyenkim.com/tu-lanh-aqua-130-lit...
# 12  https://www.nguyenkim.com/tu-lanh-aqua-90-lit-...
# 13  https://www.nguyenkim.com/tu-lanh-samsung-208-...
# 14  https://www.nguyenkim.com/tu-lanh-lg-315-lit-g...
# 15  https://www.nguyenkim.com/tu-lanh-aqua-50-lit-...
# 16  https://www.nguyenkim.com/tu-lanh-samsung-inve...
# 17  https://www.nguyenkim.com/tu-lanh-sharp-196-li...
# 18  https://www.nguyenkim.com/tu-lanh-hitachi-r-fg...
# 19  https://www.nguyenkim.com/tu-lanh-aqua-inverte...
# 20  https://www.nguyenkim.com/tu-lanh-hitachi-r-fw...
# 21  https://www.nguyenkim.com/tu-lanh-samsung-280-...
# 22  https://www.nguyenkim.com/tu-lanh-sharp-invert...
# 23  https://www.nguyenkim.com/tu-lanh-toshiba-inve...
# 24  https://www.nguyenkim.com/tu-lanh-toshiba-gr-a...
# 25  https://www.nguyenkim.com/tu-lanh-sharp-150-li...
# 26  https://www.nguyenkim.com/tu-lanh-samsung-inve...
# 27  https://www.nguyenkim.com/tu-lanh-hitachi-275-...
# 28  https://www.nguyenkim.com/tu-lanh-sharp-sj-x34...
# 29  https://www.nguyenkim.com/tu-lanh-toshiba-inve...
# 30  https://www.nguyenkim.com/tu-lanh-electrolux-e...
# 31  https://www.nguyenkim.com/tu-lanh-hitachi-inve...
# 32  https://www.nguyenkim.com/tu-lanh-hitachi-r-fw...
# 33  https://www.nguyenkim.com/tu-lanh-samsung-680-...

# %%
# Điện thoại
from selenium import webdriver as wb
import pandas as pd
from tqdm import tqdm
import time

webD = wb.Chrome('C:\\Users\\Admin\\Downloads\\chromedriver.exe')
webD.get('https://www.nguyenkim.com/dien-thoai-di-dong/')

hrefLinkList = []
condition = True

while condition:
    time.sleep(4)
    allInfo = webD.find_elements_by_class_name('nk-link-product')

    for eEle in allInfo:
        
        hrefLink = eEle.get_property('href')
        hrefLinkList.append(hrefLink)
    try:
        webD.find_elements_by_class_name('btn_next ')[-1].click()
    except:
        condition = False

overallinfo = []
for i in tqdm(hrefLinkList):
    webD.get(i)
    time.sleep(1)
    nameOftheProduct = webD.find_element_by_class_name('product_info_name').text
    priceoftheProduct = webD.find_element_by_class_name('nk-price-final').text
#     descOfProduct = webD.find_element_by_xpath(
#         '//*[@id="__next"]/div[1]/main/div[3]/div/div[2]/div[2]/div[1]/div[1]/div[3]/ul')
    tempJ = {'nameOftheProduct': nameOftheProduct,
             'priceoftheProduct': priceoftheProduct,
#              'descOfProduct': descOfProduct,
             'hyperlink': i}
    overallinfo.append(tempJ)

pd.DataFrame(overallinfo)
# Out:
#  46%|████████████████████████████████████▌                                           | 211/461 [09:43<11:31,  2.76s/it]
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-13-41475ad94e60> in <module>
#      28     webD.get(i)
#      29     time.sleep(1)
# ---> 30     nameOftheProduct = webD.find_element_by_class_name('product_info_name').text
#      31     priceoftheProduct = webD.find_element_by_class_name('nk-price-final').text
#      32 #     descOfProduct = webD.find_element_by_xpath(
#
# c:\python38\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# c:\python38\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# c:\python38\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\python38\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=84.0.4147.105)

# %%
# Máy ảnh
from selenium import webdriver as wb
import pandas as pd
from tqdm import tqdm
import time

webD = wb.Chrome('C:\\Users\\Admin\\Downloads\\chromedriver.exe')
webD.get('https://www.nguyenkim.com/may-anh/')

hrefLinkList = []
condition = True

while condition:
    time.sleep(4)
    allInfo = webD.find_elements_by_class_name('nk-link-product')

    for eEle in allInfo:
        
        hrefLink = eEle.get_property('href')
        hrefLinkList.append(hrefLink)
    try:
        webD.find_elements_by_class_name('btn_next ')[-1].click()
    except:
        condition = False

overallinfo = []
for i in tqdm(hrefLinkList):
    webD.get(i)
    time.sleep(1)
    nameOftheProduct = webD.find_element_by_class_name('product_info_name').text
    priceoftheProduct = webD.find_element_by_class_name('nk-price-final').text
#     descOfProduct = webD.find_element_by_xpath(
#         '//*[@id="__next"]/div[1]/main/div[3]/div/div[2]/div[2]/div[1]/div[1]/div[3]/ul')
    tempJ = {'nameOftheProduct': nameOftheProduct,
             'priceoftheProduct': priceoftheProduct,
#              'descOfProduct': descOfProduct,
             'hyperlink': i}
    overallinfo.append(tempJ)

pd.DataFrame(overallinfo)
# Out:
#  69%|████████████████████████████████████████████████████████▍                         | 31/45 [01:11<00:32,  2.31s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1f28943ff730> in <module>
#      26 overallinfo = []
#      27 for i in tqdm(hrefLinkList):
# ---> 28     webD.get(i)
#      29     time.sleep(1)
#      30     nameOftheProduct = webD.find_element_by_class_name('product_info_name').text
#
# c:\python38\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# c:\python38\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# c:\python38\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# c:\python38\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# c:\python38\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77             )
#      78         else:
# ---> 79             return self.request_encode_body(
#      80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#
# c:\python38\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# c:\python38\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# c:\python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# c:\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\python38\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# c:\python38\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# c:\python38\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# c:\python38\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# c:\python38\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# TV HC

from selenium import webdriver as wb
import pandas as pd
from tqdm import tqdm
import time

webD = wb.Chrome('C:\\Users\\Admin\\Downloads\\chromedriver.exe')
webD.get('https://hc.com.vn/ords/c--tivi')

hrefLinkList = []
condition = True
page = 2
while condition:
    time.sleep(4)
    allInfo = webD.find_elements_by_class_name('product-item-container')

    for eEle in allInfo:
        link = eEle.find_elements_by_class('right-block')
        temp = link.find_elements_by_tag_name('h3')
        a = temp.find_elements_by_tag_name('a')
        hrefLink = link.get_property('href')
        hrefLinkList.append(hrefLink)
    try:
        webD.find_elements_by_id('PAGE_'+page+'')[-1].click()
        page = page + 1
    except:
        condition = False

overallinfo = []
for i in tqdm(hrefLinkList):
    webD.get(i)
    time.sleep(1)
    nameOftheProduct = webD.find_element_by_class_name('product_info_name').text
    priceoftheProduct = webD.find_element_by_class_name('nk-price-final').text
#     descOfProduct = webD.find_element_by_xpath(
#         '//*[@id="__next"]/div[1]/main/div[3]/div/div[2]/div[2]/div[1]/div[1]/div[3]/ul')
    tempJ = {'nameOftheProduct': nameOftheProduct,
             'priceoftheProduct': priceoftheProduct,
#              'descOfProduct': descOfProduct,
             'hyperlink': i}
    overallinfo.append(tempJ)

pd.DataFrame(overallinfo)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f17655cc0cab> in <module>
#      17
#      18     for eEle in allInfo:
# ---> 19         link = eEle.find_elements_by_class('right-block')
#      20         temp = link.find_elements_by_tag_name('h3')
#      21         a = temp.find_elements_by_tag_name('a')
#
# AttributeError: 'WebElement' object has no attribute 'find_elements_by_class'

# %%
# Máy ảnh
from selenium import webdriver as wb
import pandas as pd
from tqdm import tqdm
import time

webD = wb.Chrome('C:\\Users\\Admin\\Downloads\\chromedriver.exe')
webD.get('https://www.nguyenkim.com/may-tinh-xach-tay/')

hrefLinkList = []
condition = True

while condition:
    time.sleep(4)
    allInfo = webD.find_elements_by_class_name('nk-link-product')

    for eEle in allInfo:
        
        hrefLink = eEle.get_property('href')
        hrefLinkList.append(hrefLink)
    try:
        webD.find_elements_by_class_name('btn_next ')[-1].click()
    except:
        condition = False

overallinfo = []
for i in tqdm(hrefLinkList):
    webD.get(i)
    time.sleep(1)
    nameOftheProduct = webD.find_element_by_class_name('product_info_name').text
    priceoftheProduct = webD.find_element_by_class_name('nk-price-final').text
#     descOfProduct = webD.find_element_by_xpath(
#         '//*[@id="__next"]/div[1]/main/div[3]/div/div[2]/div[2]/div[1]/div[1]/div[3]/ul')
    tempJ = {'nameOftheProduct': nameOftheProduct,
             'priceoftheProduct': priceoftheProduct,
#              'descOfProduct': descOfProduct,
             'hyperlink': i}
    overallinfo.append(tempJ)

pd.DataFrame(overallinfo)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 317/317 [14:43<00:00,  2.79s/it]
#                                       nameOftheProduct priceoftheProduct  \
# 0         Acer Aspire 5 A514-53-50JA i5-1035G1 14 inch       15.690.000đ
# 1                            Laptop Asus A412FA-EK734T       16.690.000đ
# 2                     Dell Inspiron 3593(70211826) Đen       21.490.000đ
# 3                      Dell Vostro 3490 (70207360) Đen       15.890.000đ
# 4                     Laptop HP 14s-dq1022tu (8QN41PA)       17.690.000đ
# ..                                                 ...               ...
# 312    Asus VivoBook 14 A412DA-EK144T R5-3500U 14 inch       14.490.000đ
# 313        Lenovo V14-IIL i5-1035G1 14 Inch 82C400W4VN       13.290.000đ
# 314           HP 14S-CF0135TU i3-8130U 14 inch 1V884PA       10.190.000đ
# 315                          Laptop Asus X509UA-EJ116T        8.550.000đ
# 316  Dell Latidude 3400 CTO i5-8265U 14 inch L3400I...       16.490.000đ
#
#                                              hyperlink
# 0    https://www.nguyenkim.com/acer-aspire-5-a514-5...
# 1    https://www.nguyenkim.com/laptop-asus-a412fa-e...
# 2    https://www.nguyenkim.com/laptop-dell-inspiron...
# 3    https://www.nguyenkim.com/laptop-dell-vostro-3...
# 4    https://www.nguyenkim.com/laptop-hp-14s-dq1022...
# ..                                                 ...
# 312  https://www.nguyenkim.com/asus-vivobook-14-r5-...
# 313  https://www.nguyenkim.com/lenovo-v14-iil-i5-10...
# 314  https://www.nguyenkim.com/hp-14s-cf0135tu-i3-8...
# 315  https://www.nguyenkim.com/laptop-asus-x509ua-e...
# 316  https://www.nguyenkim.com/dell-latidude-3400-c...
#
# [317 rows x 3 columns]

# %%
from selenium import webdriver as wb
import pandas as pd
from tqdm import tqdm
import time
import json

webD = wb.Chrome('C:\\Users\\Admin\\Downloads\\chromedriver.exe')




hrefLinkList = []
condition = True

data = []
overallinfo = []

webD.get('https://www.nguyenkim.com/hp-250-g7-i3-1005g1-15.6-inch-15h40pa.html')
time.sleep(0.25)

nameOftheProduct = webD.find_element_by_class_name('product_info_name').text
priceoftheProduct = webD.find_element_by_class_name('nk-price-final').text
linkProductImage = webD.find_element_by_class_name('img-full-width')
src = linkProductImage.get_property('src')
#     descOfProduct = webD.find_element_by_xpath(
#         '//*[@id="__next"]/div[1]/main/div[3]/div/div[2]/div[2]/div[1]/div[1]/div[3]/ul')
try:
    supplier = webD.find_element_by_xpath('//*[@id="content_features"]/div[1]/div[2]/div/table/tbody/tr[3]/td[2]').text
    if supplier != 'Asus' and supplier != 'Dell' and supplier != 'Acer' and supplier != 'MSI' and supplier != 'HP' and supplier != 'Apple' and supplier != 'Lenovo' and supplier != 'LG':
        supplier = webD.find_element_by_xpath('//*[@id="content_features"]/div[1]/div[2]/div/table/tbody/tr[2]/td[2]').text
    supID = 0
    if supplier == 'Asus':
        supID = 2
    elif supplier == 'Dell':
        supID = 1
    elif supplier == 'Acer':
        supID = 3
    elif supplier == 'MSI':
        supID = 4
    elif supplier == 'HP':
        supID = 8
    elif supplier == 'Apple':
        supID = 7
    elif supplier == 'Lenovo':
        supID = 5
    elif supplier == 'LG':
        supID = 6
    tempJ = {'nameOftheProduct': nameOftheProduct,
             'priceoftheProduct': priceoftheProduct,
             #              'descOfProduct': descOfProduct,
             'hyperlink': i,
             'CategoryID': 5,
             'CompanyID': 1,
             'SupplierID': supID,
             'linkProductImage': src
             }
    data.append(tempJ)
except :
    tempJ = {'nameOftheProduct': nameOftheProduct,
             'priceoftheProduct': priceoftheProduct,
             #              'descOfProduct': descOfProduct,
             'hyperlink': i,
             'CategoryID': 5,
             'CompanyID': 1,
             'SupplierID': 0,
             'linkProductImage': linkProductImage
             }
    data.append(tempJ)

pd.DataFrame(data)
#Writing to JSON File


for i in data:
    print(i)
# Out:
# {'nameOftheProduct': 'HP 250 G7 i3-1005G1 15.6 inch 15H40PA', 'priceoftheProduct': '10.090.000đ', 'hyperlink': {'nameOftheProduct': 'HP 250 G7 i3-1005G1 15.6 inch 15H40PA', 'priceoftheProduct': '10.090.000đ', 'hyperlink': 'https://www.nguyenkim.com/asus-x509j-i5-1035g1-15.6-inch-x509jp-ej013t.html', 'CategoryID': 5, 'CompanyID': 1, 'SupplierID': 8, 'linkProductImage': <selenium.webdriver.remote.webelement.WebElement (session="e3591bf2a81f4e889f6a4cff82a6897c", element="97d19fed-f76f-4fcf-b473-617f43b95f5d")>}, 'CategoryID': 5, 'CompanyID': 1, 'SupplierID': 8, 'linkProductImage': 'https://cdn.nguyenkimmall.com/images/thumbnails/600/336/detailed/675/10046969-hp-250-g7-i3-1005g1-15-6-inch-15h40pa-1.jpg'}
